# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
#import statsmodels.api as sm

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Farhingithub/DataSet/main/Boston(1).csv')

# %%
df
# Out:
#      Index      crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio   black  lstat  medv
# 0        1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3  396.90   4.98  24.0
# 1        2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8  396.90   9.14  21.6
# 2        3   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8  392.83   4.03  34.7
# 3        4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7  394.63   2.94  33.4
# 4        5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7  396.90   5.33  36.2
# 5        6   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7  394.12   5.21  28.7
# 6        7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2  395.60  12.43  22.9
# 7        8   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2  396.90  19.15  27.1
# 8        9   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2  386.63  29.93  16.5
# 9       10   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2  386.71  17.10  18.9
# 10      11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311     15.2  392.52  20.45  15.0
# 11      12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311     15.2  396.90  13.27  18.9
# 12      13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311     15.2  390.50  15.71  21.7
# 13      14   0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307     21.0  396.90   8.26  20.4
# 14      15   0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307     21.0  380.02  10.26  18.2
# 15      16   0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307     21.0  395.62   8.47  19.9
# 16      17   1.05393   0.0   8.14     0  0.538  5.935   29.3  4.4986    4  307     21.0  386.85   6.58  23.1
# 17      18   0.78420   0.0   8.14     0  0.538  5.990   81.7  4.2579    4  307     21.0  386.75  14.67  17.5
# 18      19   0.80271   0.0   8.14     0  0.538  5.456   36.6  3.7965    4  307     21.0  288.99  11.69  20.2
# 19      20   0.72580   0.0   8.14     0  0.538  5.727   69.5  3.7965    4  307     21.0  390.95  11.28  18.2
# 20      21   1.25179   0.0   8.14     0  0.538  5.570   98.1  3.7979    4  307     21.0  376.57  21.02  13.6
# 21      22   0.85204   0.0   8.14     0  0.538  5.965   89.2  4.0123    4  307     21.0  392.53  13.83  19.6
# 492    493   0.11132   0.0  27.74     0  0.609  5.983   83.5  2.1099    4  711     20.1  396.90  13.35  20.1
# 493    494   0.17331   0.0   9.69     0  0.585  5.707   54.0  2.3817    6  391     19.2  396.90  12.01  21.8
# 494    495   0.27957   0.0   9.69     0  0.585  5.926   42.6  2.3817    6  391     19.2  396.90  13.59  24.5
# 495    496   0.17899   0.0   9.69     0  0.585  5.670   28.8  2.7986    6  391     19.2  393.29  17.60  23.1
# 496    497   0.28960   0.0   9.69     0  0.585  5.390   72.9  2.7986    6  391     19.2  396.90  21.14  19.7
# 497    498   0.26838   0.0   9.69     0  0.585  5.794   70.6  2.8927    6  391     19.2  396.90  14.10  18.3
# 498    499   0.23912   0.0   9.69     0  0.585  6.019   65.3  2.4091    6  391     19.2  396.90  12.92  21.2
# 499    500   0.17783   0.0   9.69     0  0.585  5.569   73.5  2.3999    6  391     19.2  395.77  15.10  17.5
# 500    501   0.22438   0.0   9.69     0  0.585  6.027   79.7  2.4982    6  391     19.2  396.90  14.33  16.8
# 501    502   0.06263   0.0  11.93     0  0.573  6.593   69.1  2.4786    1  273     21.0  391.99   9.67  22.4
# 502    503   0.04527   0.0  11.93     0  0.573  6.120   76.7  2.2875    1  273     21.0  396.90   9.08  20.6
# 503    504   0.06076   0.0  11.93     0  0.573  6.976   91.0  2.1675    1  273     21.0  396.90   5.64  23.9
# 504    505   0.10959   0.0  11.93     0  0.573  6.794   89.3  2.3889    1  273     21.0  393.45   6.48  22.0
# 505    506   0.04741   0.0  11.93     0  0.573  6.030   80.8  2.5050    1  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
df.head()
# Out:
#    Index     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio   black  lstat  medv
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  396.90   4.98  24.0
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8  396.90   9.14  21.6
# 2      3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8  392.83   4.03  34.7
# 3      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7  394.63   2.94  33.4
# 4      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7  396.90   5.33  36.2

# %%
df.shape
# Out:
# (506, 15)

# %%
x=df.drop(['Index','medv'],axis=1)

# %%
x.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat'],
#       dtype='object')

# %%
y=df['medv']

# %%
#using pearson correlation 
plt.figure(figsize=(10,6))
cor = df.corr()
sns.heatmap(cor,annot=True, cmap="gist_rainbow")

# %%
#correlation with output variable
cor_target =abs(cor['medv'])
#selection highly correlated features
relevant_features=cor_target[cor_target>0.5]
relevant_features
# Out:
# rm         0.695360
# ptratio    0.507787
# lstat      0.737663
# medv       1.000000
# Name: medv, dtype: float64

# %%
from matplotlib import colormaps
list(colormaps)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-1c1181816c4e> in <module>
# ----> 1 from matplotlib import colormaps
#       2 list(colormaps)
#
# ImportError: cannot import name 'colormaps' from 'matplotlib' (C:\Users\Prwatech\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py)
